# %% [markdown]
# # Hybrid Plant with Battery Storage Example
# ---
# In this example, we will explore how to simulate a hybrid renewable energy system that includes both wind and solar power sources, along with battery energy storage. The battery uses the default dispatch model,simple dispatch, which uses a profit maximization objective function.
#
# The key aspects we will cover include setting up the simulation environment, configuring the system, running the simulation, and visualizing the results.

# %% [markdown]
# ### Import Required Modules
# Begin by importing the necessary modules for the simulation.

# %%
from hopp.simulation import HoppInterface
from hopp.tools.dispatch.plot_tools import (
    plot_battery_output, plot_battery_dispatch_error, plot_generation_profile
)

# %% [markdown]
# ### Create the Simulation Model
# Instantiate the `HoppInterface` class by providing a YAML configuration.
#
# In order to configure the battery dispatch model, ensure that you include a `grid_resource_file` within the `site` section, and incorporate the `battery` size and capacity into the `technologies` section of the YAML configuration.

# %%
hi = HoppInterface("./inputs/03-wind-solar-battery.yaml")

# %% [markdown]
# ### Run the Simulation
# Simulate the hybrid renewable energy system for a specified number of years (in this case, 20 years).

# %%
hi.simulate(project_life=20)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 hi.simulate(project_life=20)
#
# File D:\python\HOPP-3.2.0\hopp\simulation\hopp_interface.py:49, in HoppInterface.simulate(self, project_life, lifetime_sim)
#      48 def simulate(self, project_life: int = 25, lifetime_sim: bool = False):
# ---> 49     self.hopp.simulate(project_life, lifetime_sim)
#
# File D:\python\HOPP-3.2.0\hopp\simulation\hopp.py:44, in Hopp.simulate(self, project_life, lifetime_sim)
#      43 def simulate(self, project_life: int = 25, lifetime_sim: bool = False):
# ---> 44     self.system.simulate(project_life, lifetime_sim)
#
# File D:\python\HOPP-3.2.0\hopp\simulation\hybrid_simulation.py:796, in HybridSimulation.simulate(self, project_life, lifetime_sim)
#     786 def simulate(self,
#     787              project_life: int = 25,
#     788              lifetime_sim = False):
#     789     """
#     790     Runs the individual system models then combines the financials
#     791
#    (...)
#     794     :return:
#     795     """
# --> 796     self.simulate_power(project_life, lifetime_sim)
#     797     self.calculate_installed_cost()
#     798     self.calculate_financials()
#
# File D:\python\HOPP-3.2.0\hopp\simulation\hybrid_simulation.py:698, in HybridSimulation.simulate_power(self, project_life, lifetime_sim)
#     695         model.simulate_power(project_life, lifetime_sim)
#     697 # simulate dispatchable systems using dispatch optimization
# --> 698 self.dispatch_builder.simulate_power()
#     700 # Put the hybrid together for grid simulation
#     701 hybrid_size_kw = 0
#
# File D:\python\HOPP-3.2.0\hopp\simulation\technologies\dispatch\hybrid_dispatch_builder_solver.py:491, in HybridDispatchBuilderSolver.simulate_power(self)
#     489             if (i % 73) == 0:
#     490                 logger.info("\t {:.0f} % complete".format(i * 20 / 73))
# --> 491             self.simulate_with_dispatch(t)
#     492 else:
#     494     initial_states = {
#     495         tech: {"day": [], "soc": [], "load": []}
#     496         for tech in ["trough", "tower", "battery"]
#     497         if tech in self.power_sources.keys()
#     498     }  # List of known charge states at 12 am from completed simulations
#
# File D:\python\HOPP-3.2.0\hopp\simulation\technologies\dispatch\hybrid_dispatch_builder_solver.py:649, in HybridDispatchBuilderSolver.simulate_with_dispatch(self, start_time, n_days, initial_soc, n_initial_sims)
#     646     self.battery_heuristic()
#     647     # TODO: we could just run the csp model without dispatch here
#     648 else:
# --> 649     self.solve_dispatch_model(start_time, n_days)
#     651 store_outputs = True
#     652 battery_sim_start_time = sim_start_time
#
# File D:\python\HOPP-3.2.0\hopp\simulation\technologies\dispatch\hybrid_dispatch_builder_solver.py:141, in HybridDispatchBuilderSolver.solve_dispatch_model(self, start_time, n_days)
#     139     solver_results = self.glpk_solve()
#     140 elif self.options.solver == "cbc":
# --> 141     solver_results = self.cbc_solve()
#     142 elif self.options.solver == "xpress":
#     143     solver_results = self.xpress_solve()
#
# File D:\python\HOPP-3.2.0\hopp\simulation\technologies\dispatch\hybrid_dispatch_builder_solver.py:302, in HybridDispatchBuilderSolver.cbc_solve(self)
#     301 def cbc_solve(self):
# --> 302     return HybridDispatchBuilderSolver.cbc_solve_call(
#     303         self.pyomo_model, self.options.log_name, self.options.solver_options
#     304     )
#
# File D:\python\HOPP-3.2.0\hopp\simulation\technologies\dispatch\hybrid_dispatch_builder_solver.py:286, in HybridDispatchBuilderSolver.cbc_solve_call(pyomo_model, log_name, user_solver_options)
#     284     else:
#     285         solver = pyomo.SolverFactory("cbc", executable=cbc_path, solver_io="nl")
# --> 286         results = solver.solve(pyomo_model, options=solver_options.constructed)
#     287 elif sys.platform == "darwin" or sys.platform == "linux":
#     288     solver = pyomo.SolverFactory("cbc")
#
# File D:\conda\envs\HOPP_new\lib\site-packages\pyomo\opt\base\solvers.py:598, in OptSolver.solve(self, *args, **kwds)
#     594 try:
#     595     # we're good to go.
#     596     initial_time = time.time()
# --> 598     self._presolve(*args, **kwds)
#     600     presolve_completion_time = time.time()
#     601     if self._report_timing:
#
# File D:\conda\envs\HOPP_new\lib\site-packages\pyomo\solvers\plugins\solvers\CBCplugin.py:261, in CBCSHELL._presolve(self, *args, **kwds)
#     253             logger.warning(
#     254                 "warmstart_file points to a file on a drive "
#     255                 "different from the current working directory.  "
#     256                 "CBC is likely to (silently) ignore the warmstart."
#     257             )
#     259 # let the base class handle any remaining keywords/actions.
#     260 # let the base class handle any remaining keywords/actions.
# --> 261 super(CBCSHELL, self)._presolve(*args, **kwds)
#     263 # NB: we must let the base class presolve run first so that the
#     264 # symbol_map is actually constructed!
#     266 if (len(args) > 0) and (not isinstance(args[0], str)):
#
# File D:\conda\envs\HOPP_new\lib\site-packages\pyomo\opt\solver\shellcmd.py:241, in SystemCallSolver._presolve(self, *args, **kwds)
#     237 self._log_file = self._command.log_file
#     238 #
#     239 # The pre-cleanup is probably unnecessary, but also not harmful.
#     240 #
# --> 241 if (self._log_file is not None) and os.path.exists(self._log_file):
#     242     os.remove(self._log_file)
#     243 if (self._soln_file is not None) and os.path.exists(self._soln_file):
#
# File D:\conda\envs\HOPP_new\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ### Print Simulation Results
# Access and display various simulation results, including annual energies, net present values (NPVs), and total revenues.

# %%
hybrid_plant = hi.system

print("Output after losses over gross output:",
      hybrid_plant.wind.value("annual_energy") / hybrid_plant.wind.value("annual_gross_energy"))

# Save the outputs
annual_energies = hybrid_plant.annual_energies
npvs = hybrid_plant.net_present_values
revs = hybrid_plant.total_revenues

print("Annual Energies:")
print(annual_energies)

print("Net Present Values:")
print(npvs)

print("Total Revenues:")
print(revs)

# %% [markdown]
# ### Visualize Simulation Results (Optional)
# Optionally, you can visualize the simulation results using plots. Several functions are provided for plotting battery output, generation profiles, and dispatch errors.

# %%
plot_battery_dispatch_error(hybrid_plant)

# %%
plot_battery_output(hybrid_plant)

# %%
plot_generation_profile(hybrid_plant)
