# %% [markdown]
# # Simple Wind and Solar Hybrid Plant Example
# ---
# In this example, we will walk through the process of simulating a hybrid renewable energy system using the Hybrid Optimization Performance Platform ([HOPP](https://github.com/NREL/HOPP)) library. We will simulate a hybrid system at a given location consisting of both wind and solar energy, and show how to access the simulation outputs.

# %% [markdown]
# ### Import Required Modules
# We start by importing the necessary modules and setting up our working environment.

# %%
from hopp.simulation import HoppInterface
# Out:
# C:\Users\22462\PycharmProjects\Multi-wind_simulation\examples\log\hybrid_systems_2025-10-30T17.07.04.802003.log

# %% [markdown]
# ### Create the HOPP Model
# To generate the HOPP Model, instantiate the `HoppInterface` class and supply the required YAML configuration.
#
# Within the YAML configuration, you have the flexibility to define the plant's location details and configure the associated technologies, in this case wind and solar pv.
#
# In this example, we use the Flatirons site as a sample location and configure the wind and solar data for this particular site using pre-existing data files.

# %%
hi = HoppInterface("./inputs/01-wind-solar.yaml")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hi = HoppInterface("./inputs/01-wind-solar.yaml")
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\simulation\hopp_interface.py:37, in HoppInterface.__init__(self, configuration)
#      36 def __init__(self, configuration: Union[dict, str, Path]):
# ---> 37     self.reinitialize(configuration=configuration)
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\simulation\hopp_interface.py:43, in HoppInterface.reinitialize(self, configuration)
#      40 self.configuration = configuration
#      42 if isinstance(self.configuration, (str, Path)):
# ---> 43     self.hopp = Hopp.from_file(self.configuration)
#      45 elif isinstance(self.configuration, dict):
#      46     self.hopp = Hopp.from_dict(self.configuration)
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\simulation\hopp.py:69, in Hopp.from_file(cls, input_file_path, filetype)
#      67 else:
#      68     raise ValueError("Supported import filetype is YAML")
# ---> 69 return Hopp.from_dict(input_dict)
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\type_dec.py:195, in FromDictMixin.from_dict(cls, data)
#     190 if undefined:
#     191     raise AttributeError(
#     192         f"The class defintion for {cls.__name__} is missing the following inputs: "
#     193         f"{undefined}"
#     194     )
# --> 195 return cls(**kwargs)
#
# File <attrs generated methods hopp.simulation.hopp.Hopp>:32, in __init__(self, site, technologies, name, config)
#      30 _setattr('name', __attr_converter_name(name))
#      31 _setattr('config', config)
# ---> 32 self.__attrs_post_init__()
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\simulation\hopp.py:27, in Hopp.__attrs_post_init__(self)
#      24 self.config = self.config or {}
#      26 if isinstance(self.site, dict):
# ---> 27     site = SiteInfo.from_dict(self.site)
#      28 else:
#      29     site = self.site
#
# File ~\PycharmProjects\Multi-wind_simulation\hopp\type_dec.py:178, in FromDictMixin.from_dict(cls, data)
#     176 extra_args = [d for d in data if d not in class_attr_names]
#     177 if len(extra_args):
# --> 178     raise AttributeError(
#     179         f"The initialization for {cls.__name__} was given extraneous inputs: {extra_args}"
#     180     )
#     182 kwargs = {a.name: data[a.name] for a in cls.__attrs_attrs__ if a.name in data and a.init}
#     184 # Map the inputs must be provided: 1) must be initialized, 2) no default value defined
#
# AttributeError: The initialization for SiteInfo was given extraneous inputs: ['wind_resource_file']

# %% [markdown]
# ### Run the Simulation
# Simulate the hybrid renewable energy system for a specified number of years (in this case, 25 years).

# %%
hi.simulate(25)

# %% [markdown]
# ### Retrieve and Display Results
# Access the simulation results, including annual energies, capacity factors and net present values (NPVs), and print them to the console.

# %%
hybrid_plant = hi.system

annual_energies = hybrid_plant.annual_energies
npvs = hybrid_plant.net_present_values
cf = hybrid_plant.capacity_factors

wind_installed_cost = hybrid_plant.wind.total_installed_cost
solar_installed_cost = hybrid_plant.pv.total_installed_cost
hybrid_installed_cost = hybrid_plant.grid.total_installed_cost

print("Wind Installed Cost: {}".format(wind_installed_cost))
print("Solar Installed Cost: {}".format(solar_installed_cost))
print("Hybrid Installed Cost: {}".format(hybrid_installed_cost))

print("Wind NPV: {}".format(hybrid_plant.net_present_values.wind))
print("Solar NPV: {}".format(hybrid_plant.net_present_values.pv))
print("Hybrid NPV: {}".format(hybrid_plant.net_present_values.hybrid))

print(annual_energies)
print(cf)
print(npvs)
# Out:
# Wind Installed Cost: 72700000.0
# Solar Installed Cost: 48000000.0
# Hybrid Installed Cost: 120700000.0
# Wind NPV: -47401363.61809909
# Solar NPV: -33636480.232181095
# Hybrid NPV: -83204102.48278144
# {"pv": 104289820.46059448, "wind": 156936144.3525474, "hybrid": 250449987.43150324}
# {"pv": 30.95359968008512, "wind": 35.830169943503975, "hybrid": 33.70992200288708}
# {"pv": -33636480.232181095, "wind": -47401363.61809909, "hybrid": -83204102.48278144}
